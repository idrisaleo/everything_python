# %%
class HallOfFame:
  def __init__(self, club, player, year):
    self.club = club
    self.player = player
    self.year = year


player1 = HallOfFame('arsenal', 'bergkamp', '1995-2006')
player2= HallOfFame('newcastle', 'shearer', '1996-2006')
player3= HallOfFame('liverpool', 'rush', '1988-1996')


class Mammalia:
  def __init__(self, name, diet, gestation, habitat):
    self.name = name
    self.diet = diet
    self.gestation = gestation
    self.habitat = habitat



animal1 = Mammalia('walrus', 'carnivore', 480, 'water')
animal2 = Mammalia('gorilla', 'omnivore', 260, 'land')
animal3 = Mammalia('Bison', 'herbivore', 217, 'land')
animal4 = Mammalia('Hippopotamus', 'omnivore', 250, 'amphibian')



# print(animal4.habitat)


class AcMilan:
  def __init__(self, position, nationality, number, name, age):
    self.position = position
    self.nationality = nationality
    self.number = number
    self.name = name

  def squadra_milan(self, goose):
   # print(f'this are the hardworking milan player')
    

#gk = AcMilan('goalkeeper', 'France', 16, 'Maignan', 17)
#cb = AcMilan('defender', 'England', 23, 'Tomori', 34)
#mf = AcMilan('midfielder', 'Italy', 8, 'Tonali', 35)
#st = AcMilan('striker', 'Sweden', 11, 'Ibrahimovic', 47)
