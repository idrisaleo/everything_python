# %%
import pandas as pd
df = pd.DataFrame({'Manager': ['Milan, Pioli',
                              'Inter, Inzaghi',
                              'Juventus, Allegri',
                              'Lazio, Sarri',
                              'Roma, Mourinho'],
                   
                   'Age': [56,46,54,63,59],
                   
                   'Birthplace': ['Parma', 'Piacenza', 'Livorno', 'Naples', 'Setubal'],
                   
                   'Heights': [1.83, 1.85, 1.86, 1.89, 1.76]}

)  ## creating a dataframe

# %%
#df['Manager'] ## a single column is a Series
#df.max() ## to show the max value
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Manager     5 non-null      object
#  1   Age         5 non-null      int64
#  2   Birthplace  5 non-null      object
#  3   Heights     5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %%
feet = pd.Series([1.83, 1.85, 1.86, 1.89, 1.76], name='heights')  ## creating a Series
feet
# Out:
# 0    1.83
# 1    1.85
# 2    1.86
# 3    1.89
# 4    1.76
# Name: heights, dtype: float64

# %%
energy = pd.read_csv('C:/Users/Idris Idris/Downloads/wec.csv')

#energy.to_excel('power.xlsx', sheet_name='power_usage', index=False)

#kola = pd.read_excel('power.xlsx', sheet_name='power_outage')

#energy.head(10)
#type(energy['country']) ## to determine the type of data

#energy_year = energy[energy['country']=='nigeria'].head(10)

energy[['country', 'year', 'iso_code']].shape
# Out:
# (17432, 3)

# %%
df[df['Heights'] > 1.79] ## you will place inside everything u want to compare......
df.sort_values('Heights', ascending=False)
# Out:
#              Manager  Age Birthplace  Heights
# 3       Lazio, Sarri   63     Naples     1.89
# 2  Juventus, Allegri   54    Livorno     1.86
# 1     Inter, Inzaghi   46   Piacenza     1.85
# 0       Milan, Pioli   56      Parma     1.83
# 4     Roma, Mourinho   59    Setubal     1.76

# %%
signings = pd.read_csv('./documents/signings.csv')
highest_trans = signings[signings['Transfer_fee']=='222000000']

# %%
signings[signings['Team_to'].isin(['Arsenal', 'AC Milan'])] ## to know weda the team_to column has either of ac milan or arsenal

signings[(signings['Team_to']=='AC Milan') | (signings['Team_to']=='Chelsea')]
# Out:
#                          Name            Position  Age        Team_from  \
# 10    Jimmy Floyd Hasselbaink      Centre-Forward   28  Atlético Madrid
# 17                  José Mari      Centre-Forward   21  Atlético Madrid
# 25           Fernando Redondo  Defensive Midfield   31      Real Madrid
# 31           Kakhaber Kaladze         Centre-Back   22      Dynamo Kyiv
# 41           Jesper Grönkjaer         Left Winger   23         AFC Ajax
# ...                       ...                 ...  ...              ...
# 4301             Ross Barkley  Attacking Midfield   24          Everton
# 4313        Ricardo Rodríguez           Left-Back   24    VfL Wolfsburg
# 4462                 Jorginho  Defensive Midfield   26       SSC Napoli
# 4498           Nikola Kalinic      Centre-Forward   30       Fiorentina
# 4658             Fabio Borini         Left Winger   27       Sunderland
#
#          League_from   Team_to       League_to     Season  Market_value  \
# ...

# %%
signings[signings['Team_to'].isin(['Arsenal', 'AC Milan'])]
#signings[(signings['Team_to']=='Arsenal') | (signings['Team_to']=='Chelsea')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\IDRISI~1\AppData\Local\Temp/ipykernel_23376/2168697673.py in <module>
# ----> 1 signings[signings['Team_to'].isin(['Arsenal', 'AC Milan'])]
#       2 #signings[(signings['Team_to']=='Arsenal') | (signings['Team_to']=='Chelsea')]
#
# NameError: name 'signings' is not defined

# %%
signings[signings['Name'].notna()] ## is not null
# Out:
#                    Name            Position  Age       Team_from  \
# 0             Luís Figo        Right Winger   27    FC Barcelona
# 1         Hernán Crespo      Centre-Forward   25           Parma
# 2         Marc Overmars         Left Winger   27         Arsenal
# 3     Gabriel Batistuta      Centre-Forward   31      Fiorentina
# 4        Nicolas Anelka      Centre-Forward   21     Real Madrid
# ...                 ...                 ...  ...             ...
# 4695      Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696          Tchê Tchê    Central Midfield   25       Palmeiras
# 4697      Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698         Yuya Osako      Second Striker   28      1. FC Köln
# 4699       Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from        Team_to     League_to     Season  Market_value  \
# 0             LaLiga    Real Madrid        LaLiga  2000-2001           NaN
# ...

# %%
# signings.loc[signings['League_to']== 'Serie A', 'Name'] ## players name signed in serie A
#signings.iloc[:, 0:6] ##first part is row, second part is column
cool = signings.iloc[0:5, 3] = "blank"

# %%
import matplotlib.pyplot as plt
air_quality = pd.read_csv('./documents/air.csv', index_col=0, parse_dates=True) ## d first column, parse d dates as true
air_quality.head()
#air_quality.plot()
#air_quality["station_london"].plot()
#air_quality.plot.scatter(x='station_london', y='station_paris', alpha=0.5)
air_quality.plot.box()
# Out:
# <AxesSubplot:>

# %%
[method_name
for method_name in dir(air_quality.plot)
if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.area(figsize=(12,4), subplots=True)
figs, axs = plt.subplots(figsize=(12,4))
air_quality.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration")
figs.savefig('air_quality.png')

# %%
import pandas as pd
signings.head()
parma_fio_sold = signings[signings['Team_from'].isin(['Parma', 'Fiorentina'])]
# signings.loc[signings['League_to']== 'Serie A', 'Name'] ## players name signed in serie A

trans_fee = signings.iloc[:, 9]
trans_fee.head(10)

def fib(number):
    a = 0
    b = 1
    for i in range(number)
    yield a
    temp = a
    a = b
    b = temp + a

for a in fib(200):
    print(a)
    

#wage = df1['Wage'].replace('[\€]', '', regex=True).apply(letter_to_float)
# Out:
#   File "C:\Users\IDRISI~1\AppData\Local\Temp/ipykernel_23376/465461293.py", line 12
#     for i in range(number)
#                           ^
# SyntaxError: invalid syntax

# %%
fees = signings.iloc[:, 9]
fees.head()
# Out:
# 0    60000000
# 1    56810000
# 2    40000000
# 3    36150000
# 4    34500000
# Name: Transfer_fee, dtype: int64

# %%
air_quality_renamed = air_quality.rename(columns={'station_london': 'london',
                    'station_antwerp': 'antwerp',
                    'station_paris': 'paris'})
air_quality_renamed

air_quality['new_column'] = air_quality['station_london'] * 100
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      new_column
# datetime
# 2019-05-07 02:00:00      2300.0
# 2019-05-07 03:00:00      1900.0
# 2019-05-07 04:00:00      1900.0
# 2019-05-07 05:00:00      1600.0
# 2019-05-07 06:00:00         NaN

# %%
dope = pd.DataFrame({'Good': ['see', 'cool'],
             'Love': ['is', 'not']}) ## sample dataframe building

dope_rename = dope.rename(columns={'Good': 'Kolder'})## renaming columns 
dope_change_case = dope_rename.rename(columns=str.upper) ## changing the case 
dope.iloc[:, :]
# Out:
#    Good Love
# 0   see   is
# 1  cool  not

# %%
air_quality['station_antwerp'].mean() ## calculating the mean of a single column
air_quality.mean() ## mean of a dataframe

air_quality.agg({ 'station_london': ['mean', 'median', 'skew', 'max', 'min'], 
                  'station_antwerp': ['mean', 'max', 'skew', 'median']}) ## use agg to run multiple calc
# Out:
#         station_london  station_antwerp
# mean         24.777090        25.778947
# median       25.000000        23.000000
# skew          0.375548         1.082260
# max          97.000000        74.500000
# min           0.000000              NaN

# %%
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
# Out:
#   File "C:\Users\IDRISI~1\AppData\Local\Temp/ipykernel_3616/464977228.py", line 1
#     signings[['Name', 'Team_to', 'League_to']].groupby('League_to).mean()
#                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
most_sign_league = signings[['Name', 'Team_to', 'League_to']].groupby('League_to') ##example of groupby
most_sign_league.head(5)
# Out:
#                    Name         Team_to         League_to
# 0             Luís Figo     Real Madrid            LaLiga
# 1         Hernán Crespo           Lazio           Serie A
# 2         Marc Overmars    FC Barcelona            LaLiga
# 3     Gabriel Batistuta         AS Roma           Serie A
# 4        Nicolas Anelka        Paris SG           Ligue 1
# ...                 ...             ...               ...
# 4584     Roger Martínez         América  Liga MX Apertura
# 4642        Diego Rolan  Dep. La Coruña           LaLiga2
# 4649    Milton Caraglio    CD Cruz Azul  Liga MX Apertura
# 4650    Elías Hernández    CD Cruz Azul  Liga MX Apertura
# 4664  Carlos Izquierdoz    Boca Juniors  Primera División
#
# [237 rows x 3 columns]

# %%
titanic = pd.read_csv('./documents/titanic.csv')
groupby_sex = titanic[['Sex', 'Age']].groupby('Sex').mean()
groupby_sex.head()

titanic.groupby('Sex').mean() ## give me the mean of all the columns, doing so by the SEX column
titanic.groupby('Sex')['Age'].mean() ## give me the mean of the column Age, doing so by the SEx column
titanic.groupby(['Sex', 'Pclass'])['Fare'].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic['Pclass'].value_counts() ## gives you the total number in each of the different pclass. It groups and counts
titanic.groupby('Pclass')['Pclass'].count() ## value counts is shorter way of doing groupby and count....
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic.sort_values(by='Age', ascending=False).head()
titanic.sort_values(by=['Pclass']).head()
# Out:
#      PassengerId  Survived  Pclass  \
# 445          446         1       1
# 310          311         1       1
# 309          310         1       1
# 307          308         1       1
# 306          307         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 445                          Dodge, Master. Washington    male   4.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 309                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
# 306                            Fleming, Miss. Margaret  female   NaN      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 445      2     33638   81.8583   A34        S
# 310      0     11767   83.1583   C54        C
# 309      0  PC 17485   56.9292   E36        C
# 307      0  PC 17758  108.9000   C65        C
# 306      0     17421  110.8833   NaN        C

# %%
air_quality.rename(columns=str.upper) ## change the column font
air_quality.rename(columns=str.lower)
sta_fif = air_quality[air_quality['station_antwerp']=='50.5']

# %%
only_male = titanic[titanic['Sex']=='Male']
group_embarked = only_male.sort_index().groupby('Embarked').head() 
group_embarked.head()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
from pandas import pivot_table
#titanic.head()
#titanic.pivot(columns=['Sex'], values='Age') ## making a pivot table, just like u have it in excel....
#titanic.head()
#titanic.pivot_table(columns='Sex', values='Fare', index='PassengerId', aggfunc='mean', margins=True)## margins gives you the overall calc


#titanic.groupby(['Sex', 'PassengerId']).mean()
pi = titanic.pivot(columns='Sex', values='Age')
#pi_reset = titanic.pivot(columns='Sex', values='Age').reset_index()
#pi_reset
pi_reset.melt(id_vars='index') ##anything outside of this will be melted i.e T from wide to long
# Out:
#       index     Sex  value
# 0         0  female    NaN
# 1         1  female   38.0
# 2         2  female   26.0
# 3         3  female   35.0
# 4         4  female    NaN
# ...     ...     ...    ...
# 1777    886    male   27.0
# 1778    887    male    NaN
# 1779    888    male    NaN
# 1780    889    male   26.0
# 1781    890    male   32.0
#
# [1782 rows x 3 columns]

# %%
twenty = pd.read_csv('./documents/long.csv', parse_dates=True)
twenty.head()

long = pd.read_csv('./documents/twenty.csv', parse_dates=True)
long.head()
twen = twenty[['date.utc', 'location', 'parameter', 'value']]
lo = long[['date.utc', 'location', 'parameter', 'value']]
air_combine = pd.concat([twen, lo], axis=0) ## concatenate used to combine
air_combination = pd.concat([twen, lo], keys=['pm25', 'no2']) ## keys allow for easy identification of the sep tables

# %%
newly_merged = pd.merge(long, twenty, how='left', on='location')
newly_merged.head()
# Out:
#   city_x country_x                 date.utc_x location parameter_x  value_x  \
# 0  Paris        FR  2019-06-21 00:00:00+00:00  FR04014         no2     20.0
# 1  Paris        FR  2019-06-20 23:00:00+00:00  FR04014         no2     21.8
# 2  Paris        FR  2019-06-20 22:00:00+00:00  FR04014         no2     26.5
# 3  Paris        FR  2019-06-20 21:00:00+00:00  FR04014         no2     24.9
# 4  Paris        FR  2019-06-20 20:00:00+00:00  FR04014         no2     21.4
#
#   unit_x city_y country_y date.utc_y parameter_y  value_y unit_y
# 0  µg/m³    NaN       NaN        NaN         NaN      NaN    NaN
# 1  µg/m³    NaN       NaN        NaN         NaN      NaN    NaN
# 2  µg/m³    NaN       NaN        NaN         NaN      NaN    NaN
# 3  µg/m³    NaN       NaN        NaN         NaN      NaN    NaN
# 4  µg/m³    NaN       NaN        NaN         NaN      NaN    NaN

# %%
titanic[titanic['Name'].isin(['Kola', 'Wasiu'])]
titanic[titanic["Pclass"].isin([2, 3])]
titanic[(titanic['Name']=='Kola') | (titanic['Name']== 'Wasiu')]
